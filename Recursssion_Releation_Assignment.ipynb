# %% [markdown]
# <a href="https://colab.research.google.com/github/pav16an/PWSKILLS_FULLSTACK_DATA_SCIENCE_PRO/blob/main/Recursssion_Releation_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Find the value of T(2) for the recu![IMG-20240312-WA0030.jpg](data:image/jpeg;base64,...![IMG-20240312-WA0027.jpg](data:image/jpeg;base64,...)...![IMG-20240312-WA0027.jpg](data:image/jpeg;base64,...))rrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5.

# %% [markdown]
# ## 2. Given a rec%rrence relation, solve it %sing the s%bstit%tion method:
# ## a. T(n) = T(n-1) + c

# %% [markdown]
# ![IMG-20240312-WA0027.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## b. T(n) = 2T(n/2) + n

# %% [markdown]
# ![IMG-20240312-WA0028.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## c. T(n) = 2T(n/2) + c

# %% [markdown]
# ![IMG-20240312-WA0029.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## d. T(n) = T(n/2) + c

# %% [markdown]
# ![IMG-20240312-WA0033.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 3. Given a rec%rrence relation, solve it %sing the rec%rsive tree approach:
# ##a. T(n) = 2T(n-1) +1

# %% [markdown]
# ![IMG-20240312-WA0032.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## b. T(n) = 2T(n/2) + n

# %% [markdown]
# ![IMG-20240312-WA0028.jpg](data:image/jpeg;base64,...)
